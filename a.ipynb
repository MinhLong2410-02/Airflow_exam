# %%
import json
with open(r'C:\Users\Student\Documents\minhlong\ThiGiuaKy\data_iuh_new.json', 'r', encoding='utf-8') as file:
            json_data = json.load(file)
json_data[0]
# Out:
# {'title': 'ITIA2024 - Data Science',
#  'href': 'news.html@detail@102@3245@ITIA2024-Data-Science',
#  'date': '10-03-2024',
# ...

# %%
import numpy as np
np.random.rand(1536).tolist()
# Out:
# [0.008960396088428246,
#  0.2603436084765982,
#  0.6758775208954051,
#  0.5229024689169763,
#  0.4338015711311327,
#  0.4880341949221295,
#  0.2022479247435457,
#  0.8220000238346505,
#  0.17929324624722798,
#  0.5436447584550564,
#  0.7846841019249051,
#  0.7319459166310944,
#  0.7713497105638528,
#  0.6599338247847937,
#  0.8491979671945863,
#  0.16991407690458704,
#  0.07326076594802677,
#  0.7115732711671648,
#  0.08053009138529399,
#  0.9518703643743907,
#  0.3293946076254354,
#  0.3855974923639006,
#  0.9823614883104546,
#  0.5977905007820008,
#  0.9225436208793649,
#  0.38088294383183885,
#  0.8907112107921398,
#  0.7612847030845254,
#  0.41871636024861913,
#  0.749288294966028,
#  0.19407075837979637,
#  0.7445592624868613,
#  0.3843086155270955,
#  0.7582952326939946,
#  0.8681195475323551,
#  0.8843741948020294,
#  0.09413610690310004,
#  0.14383582710912612,
#  0.31715439146201974,
#  0.38975522465952805,
#  0.8620685775735067,
#  0.4708245917086825,
# ...
